# %%
import pandas as pd
dataset = pd.read_csv("../insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset = pd.get_dummies(dataset, drop_first=True)
dataset.astype(int)
# Out:
#       age  bmi  children  charges  sex_male  smoker_yes
# 0      19   27         0    16884         0           1
# 1      18   33         1     1725         1           0
# 2      28   33         3     4449         1           0
# 3      33   22         0    21984         1           0
# 4      32   28         0     3866         1           0
# ...   ...  ...       ...      ...       ...         ...
# 1333   50   30         3    10600         1           0
# 1334   18   31         0     2205         0           0
# 1335   18   36         0     1629         0           0
# 1336   21   25         0     2007         0           0
# 1337   61   29         0    29141         0           1
#
# [1338 rows x 6 columns]

# %%
#split independent and dependenet data
indenependent = dataset[['age','bmi', 'children', 'sex_male',  'smoker_yes']]
dependent = dataset['charges']

# %%
#split into training and test Data
from sklearn.model_selection import train_test_split
xTrain, xTest, yTrain, yTest = train_test_split(indenependent, dependent, test_size=0.30, random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
xTrain = sc.fit_transform(xTrain)
xTest = sc.transform(xTest)

# %%
xTrain
# Out:
# array([[-1.5330973 , -0.40713453, -0.89833872, -0.97676557, -0.50466988],
#        [-0.03364163,  0.32855417, -0.89833872, -0.97676557, -0.50466988],
#        [ 0.89459283,  2.56690911,  3.25603402, -0.97676557, -0.50466988],
#        ...,
#        [ 0.03776102, -0.91016269, -0.89833872,  1.02378711, -0.50466988],
#        [-1.46169465,  0.76659782, -0.89833872,  1.02378711, -0.50466988],
#        [-0.46205754, -1.96596021, -0.06746417, -0.97676557, -0.50466988]])

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
param_grid = {'kernel':['rbf', 'poly', 'sigmoid' 'linear'], 'C': [10, 100, 1000, 2000, 3000], 'gamma':['auto', 'scale']}

grid = GridSearchCV(SVR(), param_grid, refit=True, verbose = 3, n_jobs=-1)

grid.fit(xTrain, yTrain)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/model_selection/_validation.py:540: FitFailedWarning:
# 50 fits failed out of a total of 150.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 6 fits failed with the following error:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.12/site-packages/sklearn/model_selection/_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "/opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "/opt/anaconda3/lib/python3.12/site-packages/sklearn/utils/_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'kernel' parameter of SVR must be a str among {'rbf', 'sigmoid', 'precomputed', 'linear', 'poly'} or a callable. Got 'sigmoidlinear' instead.
#
# --------------------------------------------------------------------------------
# 6 fits failed with the following error:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.12/site-packages/sklearn/model_selection/_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "/opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "/opt/anaconda3/lib/python3.12/site-packages/sklearn/utils/_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'kernel' parameter of SVR must be a str among {'precomputed', 'sigmoid', 'rbf', 'poly', 'linear'} or a callable. Got 'sigmoidlinear' instead.
#
# --------------------------------------------------------------------------------
# 7 fits failed with the following error:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.12/site-packages/sklearn/model_selection/_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "/opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "/opt/anaconda3/lib/python3.12/site-packages/sklearn/utils/_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'kernel' parameter of SVR must be a str among {'poly', 'precomputed', 'rbf', 'sigmoid', 'linear'} or a callable. Got 'sigmoidlinear' instead.
#
# --------------------------------------------------------------------------------
# 6 fits failed with the following error:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.12/site-packages/sklearn/model_selection/_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "/opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "/opt/anaconda3/lib/python3.12/site-packages/sklearn/utils/_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'kernel' parameter of SVR must be a str among {'precomputed', 'linear', 'sigmoid', 'poly', 'rbf'} or a callable. Got 'sigmoidlinear' instead.
#
# --------------------------------------------------------------------------------
# 3 fits failed with the following error:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.12/site-packages/sklearn/model_selection/_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "/opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "/opt/anaconda3/lib/python3.12/site-packages/sklearn/utils/_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'kernel' parameter of SVR must be a str among {'poly', 'linear', 'precomputed', 'sigmoid', 'rbf'} or a callable. Got 'sigmoidlinear' instead.
#
# --------------------------------------------------------------------------------
# 3 fits failed with the following error:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.12/site-packages/sklearn/model_selection/_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "/opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "/opt/anaconda3/lib/python3.12/site-packages/sklearn/utils/_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'kernel' parameter of SVR must be a str among {'linear', 'sigmoid', 'poly', 'precomputed', 'rbf'} or a callable. Got 'sigmoidlinear' instead.
#
# --------------------------------------------------------------------------------
# 14 fits failed with the following error:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.12/site-packages/sklearn/model_selection/_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "/opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "/opt/anaconda3/lib/python3.12/site-packages/sklearn/utils/_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'kernel' parameter of SVR must be a str among {'linear', 'precomputed', 'rbf', 'sigmoid', 'poly'} or a callable. Got 'sigmoidlinear' instead.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.12/site-packages/sklearn/model_selection/_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "/opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "/opt/anaconda3/lib/python3.12/site-packages/sklearn/utils/_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'kernel' parameter of SVR must be a str among {'precomputed', 'sigmoid', 'linear', 'poly', 'rbf'} or a callable. Got 'sigmoidlinear' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/model_selection/_search.py:1102: UserWarning: One or more of the test scores are non-finite: [-0.05662476  0.00110691         nan -0.05663427  0.00118783         nan
#   0.24302434  0.51018065         nan  0.24298241  0.5101548          nan
#   0.70662542  0.79355465         nan  0.70664116  0.79326504         nan
#   0.78339585  0.805576           nan  0.78342759  0.80558216         nan
#   0.79694094  0.80671834         nan  0.79694286  0.80674298         nan]
#   warnings.warn(
# GridSearchCV(estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [10, 100, 1000, 2000, 3000],
#                          'gamma': ['auto', 'scale'],
#                          'kernel': ['rbf', 'poly', 'sigmoidlinear']},
#              verbose=3)

# %%
#print best parameter after tuning
re = grid.cv_results_
#print(re)

grid_predictions = grid.predict(xTest)

#print classification report
from sklearn.metrics import r2_score
rScore = r2_score(yTest, grid_predictions)

print('The R-Score of the best perameter {}:'.format(grid.best_params_), rScore)
# Out:
# The R-Score of the best perameter {'C': 3000, 'gamma': 'scale', 'kernel': 'poly'}: 0.8598930084494385

# %%
tabel = pd.DataFrame.from_dict(re)

# %%
tabel
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0        0.020634      0.005421         0.009249        0.003299       10
# 1        0.015435      0.002508         0.003372        0.001384       10
# 2        0.000310      0.000119         0.000000        0.000000       10
# 3        0.014006      0.002871         0.007455        0.003915       10
# 4        0.013818      0.002848         0.001787        0.000853       10
# 5        0.000300      0.000156         0.000000        0.000000       10
# 6        0.015126      0.003472         0.004975        0.001724      100
# 7        0.013628      0.003539         0.001684        0.000816      100
# 8        0.000567      0.000294         0.000000        0.000000      100
# 9        0.011763      0.002678         0.004993        0.001875      100
# 10       0.017555      0.003660         0.001472        0.000239      100
# 11       0.000249      0.000125         0.000000        0.000000      100
# 12       0.023014      0.003616         0.006392        0.002960     1000
# 13       0.017783      0.004581         0.001734        0.000706     1000
# 14       0.000324      0.000039         0.000000        0.000000     1000
# 15       0.018426      0.002947         0.007394        0.002968     1000
# 16       0.021575      0.004927         0.002791        0.002995     1000
# 17       0.000211      0.000104         0.000000        0.000000     1000
# 18       0.020872      0.002613         0.006833        0.003175     2000
# 19       0.046208      0.005521         0.002217        0.001096     2000
# 20       0.000508      0.000245         0.000000        0.000000     2000
# 21       0.025510      0.002926         0.006422        0.003268     2000
# 22       0.030980      0.005190         0.002469        0.001566     2000
# 23       0.000317      0.000145         0.000000        0.000000     2000
# 24       0.026497      0.002230         0.005057        0.001006     3000
# 25       0.055110      0.027616         0.001685        0.000551     3000
# 26       0.000160      0.000044         0.000000        0.000000     3000
# 27       0.020472      0.002812         0.005673        0.001800     3000
# 28       0.059885      0.025372         0.001807        0.000792     3000
# 29       0.000349      0.000047         0.000000        0.000000     3000
#
#    param_gamma   param_kernel  \
# 0         auto            rbf
# 1         auto           poly
# 2         auto  sigmoidlinear
# 3        scale            rbf
# 4        scale           poly
# 5        scale  sigmoidlinear
# 6         auto            rbf
# 7         auto           poly
# 8         auto  sigmoidlinear
# 9        scale            rbf
# 10       scale           poly
# 11       scale  sigmoidlinear
# 12        auto            rbf
# 13        auto           poly
# 14        auto  sigmoidlinear
# 15       scale            rbf
# 16       scale           poly
# 17       scale  sigmoidlinear
# 18        auto            rbf
# 19        auto           poly
# 20        auto  sigmoidlinear
# 21       scale            rbf
# 22       scale           poly
# 23       scale  sigmoidlinear
# 24        auto            rbf
# 25        auto           poly
# 26        auto  sigmoidlinear
# 27       scale            rbf
# 28       scale           poly
# 29       scale  sigmoidlinear
#
#                                                params  split0_test_score  \
# 0         {'C': 10, 'gamma': 'auto', 'kernel': 'rbf'}           0.004055
# 1        {'C': 10, 'gamma': 'auto', 'kernel': 'poly'}           0.056274
# 2   {'C': 10, 'gamma': 'auto', 'kernel': 'sigmoidl...                NaN
# 3        {'C': 10, 'gamma': 'scale', 'kernel': 'rbf'}           0.004126
# 4       {'C': 10, 'gamma': 'scale', 'kernel': 'poly'}           0.054964
# 5   {'C': 10, 'gamma': 'scale', 'kernel': 'sigmoid...                NaN
# 6        {'C': 100, 'gamma': 'auto', 'kernel': 'rbf'}           0.300573
# 7       {'C': 100, 'gamma': 'auto', 'kernel': 'poly'}           0.540643
# 8   {'C': 100, 'gamma': 'auto', 'kernel': 'sigmoid...                NaN
# 9       {'C': 100, 'gamma': 'scale', 'kernel': 'rbf'}           0.301041
# 10     {'C': 100, 'gamma': 'scale', 'kernel': 'poly'}           0.537117
# 11  {'C': 100, 'gamma': 'scale', 'kernel': 'sigmoi...                NaN
# 12      {'C': 1000, 'gamma': 'auto', 'kernel': 'rbf'}           0.733044
# 13     {'C': 1000, 'gamma': 'auto', 'kernel': 'poly'}           0.829631
# 14  {'C': 1000, 'gamma': 'auto', 'kernel': 'sigmoi...                NaN
# 15     {'C': 1000, 'gamma': 'scale', 'kernel': 'rbf'}           0.733334
# 16    {'C': 1000, 'gamma': 'scale', 'kernel': 'poly'}           0.828213
# 17  {'C': 1000, 'gamma': 'scale', 'kernel': 'sigmo...                NaN
# 18      {'C': 2000, 'gamma': 'auto', 'kernel': 'rbf'}           0.814076
# 19     {'C': 2000, 'gamma': 'auto', 'kernel': 'poly'}           0.845403
# 20  {'C': 2000, 'gamma': 'auto', 'kernel': 'sigmoi...                NaN
# 21     {'C': 2000, 'gamma': 'scale', 'kernel': 'rbf'}           0.814295
# 22    {'C': 2000, 'gamma': 'scale', 'kernel': 'poly'}           0.845581
# 23  {'C': 2000, 'gamma': 'scale', 'kernel': 'sigmo...                NaN
# 24      {'C': 3000, 'gamma': 'auto', 'kernel': 'rbf'}           0.828670
# 25     {'C': 3000, 'gamma': 'auto', 'kernel': 'poly'}           0.846775
# 26  {'C': 3000, 'gamma': 'auto', 'kernel': 'sigmoi...                NaN
# 27     {'C': 3000, 'gamma': 'scale', 'kernel': 'rbf'}           0.828795
# 28    {'C': 3000, 'gamma': 'scale', 'kernel': 'poly'}           0.846874
# 29  {'C': 3000, 'gamma': 'scale', 'kernel': 'sigmo...                NaN
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.013366          -0.103821          -0.095119
# 1            0.069532          -0.045601          -0.025079
# 2                 NaN                NaN                NaN
# 3            0.013244          -0.103775          -0.095165
# 4            0.071297          -0.046513          -0.024157
# 5                 NaN                NaN                NaN
# 6            0.339474           0.173708           0.217991
# 7            0.575051           0.474839           0.535730
# 8                 NaN                NaN                NaN
# 9            0.338741           0.174086           0.217641
# 10           0.579373           0.471840           0.537966
# 11                NaN                NaN                NaN
# 12           0.746232           0.686773           0.717920
# 13           0.802622           0.799620           0.800321
# 14                NaN                NaN                NaN
# 15           0.745892           0.687037           0.717769
# 16           0.802622           0.799348           0.800587
# 17                NaN                NaN                NaN
# 18           0.781092           0.794081           0.794075
# 19           0.805639           0.816733           0.805143
# 20                NaN                NaN                NaN
# 21           0.780971           0.794227           0.793983
# 22           0.805624           0.816612           0.805133
# 23                NaN                NaN                NaN
# 24           0.790265           0.811049           0.812892
# 25           0.805323           0.817309           0.805191
# 26                NaN                NaN                NaN
# 27           0.790105           0.811123           0.812857
# 28           0.805331           0.817283           0.805239
# 29                NaN                NaN                NaN
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0           -0.101604        -0.056625        0.053504               19
# 1           -0.049592         0.001107        0.051309               18
# 2                 NaN              NaN             NaN               21
# 3           -0.101602        -0.056634        0.053486               20
# 4           -0.049652         0.001188        0.051594               17
# 5                 NaN              NaN             NaN               21
# 6            0.183375         0.243024        0.065733               15
# 7            0.424640         0.510181        0.053582               13
# 8                 NaN              NaN             NaN               21
# 9            0.183403         0.242982        0.065542               16
# 10           0.424478         0.510155        0.054955               14
# 11                NaN              NaN             NaN               21
# 12           0.649158         0.706625        0.034902               12
# 13           0.735580         0.793555        0.031072                7
# 14                NaN              NaN             NaN               21
# 15           0.649174         0.706641        0.034825               11
# 16           0.735555         0.793265        0.030757                8
# 17                NaN              NaN             NaN               21
# 18           0.733656         0.783396        0.027014               10
# 19           0.754961         0.805576        0.029233                4
# 20                NaN              NaN             NaN               21
# 21           0.733663         0.783428        0.027068                9
# 22           0.754962         0.805582        0.029272                3
# 23                NaN              NaN             NaN               21
# 24           0.741829         0.796941        0.030140                6
# 25           0.758994         0.806718        0.028279                2
# 26                NaN              NaN             NaN               21
# 27           0.741835         0.796943        0.030174                5
# 28           0.758988         0.806743        0.028307                1
# 29                NaN              NaN             NaN               21

# %%
age = float(input('Enter Age:'))
bmi = float(input('Enter BMI:'))
children = int(input('Enter Children:'))
sex_male = int(input('Enter Sex:'))
smoker_yes = int(input('Enter Smoker:'))
# Out:
# Enter Age: 30
# Enter BMI: 45
# Enter Children: 1
# Enter Sex: 1
# Enter Smoker: 0

# %%
futurePrediction = grid.predict([[age, bmi, children, sex_male, smoker_yes]])
print("Future Prediction={}".format(futurePrediction))
print(futurePrediction)
# Out:
# Future Prediction=[1381166.89201699]
# [1381166.89201699]

# %%
#Save the finalized model
import pickle
fileName = "best_svrgrid_model.sav"
pickle.dump(grid, open(fileName,'wb'))

# %%
#Read saved model
loadedModel = pickle.load(open("best_svrgrid_model.sav","rb")) #reload the model

# %%
result = loadedModel.predict([[30,45,1,1,0]]) #predict with new set of inputs
result
# Out:
# array([1381166.89201699])
