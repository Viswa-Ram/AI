# %%
import pandas as pd
dataset = pd.read_csv("../insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset = pd.get_dummies(dataset, drop_first=True)
dataset.astype(int)
# Out:
#       age  bmi  children  charges  sex_male  smoker_yes
# 0      19   27         0    16884         0           1
# 1      18   33         1     1725         1           0
# 2      28   33         3     4449         1           0
# 3      33   22         0    21984         1           0
# 4      32   28         0     3866         1           0
# ...   ...  ...       ...      ...       ...         ...
# 1333   50   30         3    10600         1           0
# 1334   18   31         0     2205         0           0
# 1335   18   36         0     1629         0           0
# 1336   21   25         0     2007         0           0
# 1337   61   29         0    29141         0           1
#
# [1338 rows x 6 columns]

# %%
#split independent and dependenet data
indenependent = dataset[['age','bmi', 'children', 'sex_male',  'smoker_yes']]
dependent = dataset['charges']

# %%
#split into training and test Data
# from sklearn.model_selection import train_test_split
# xTrain, xTest, yTrain, yTest = train_test_split(indenependent, dependent, test_size=0.30, random_state=0)

# %%
#from sklearn.preprocessing import StandardScaler
#sc = StandardScaler()
# xTrain = sc.fit_transform(xTrain)
# xTest = sc.transform(xTest)

# %%
# xTrain
# Out:
# array([[-1.5330973 , -0.40713453, -0.89833872, -0.97676557, -0.50466988],
#        [-0.03364163,  0.32855417, -0.89833872, -0.97676557, -0.50466988],
#        [ 0.89459283,  2.56690911,  3.25603402, -0.97676557, -0.50466988],
#        ...,
#        [ 0.03776102, -0.91016269, -0.89833872,  1.02378711, -0.50466988],
#        [-1.46169465,  0.76659782, -0.89833872,  1.02378711, -0.50466988],
#        [-0.46205754, -1.96596021, -0.06746417, -0.97676557, -0.50466988]])

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV

param_grid = {'criterion':['squared_error', 'absolute_error', 'friedman_mse', 'poisson'], 'max_features': [None, 'sqrt', 'log2'], 'n_estimators':[50, 100]}

grid = GridSearchCV(RandomForestRegressor(), param_grid, refit=True, verbose = 3, n_jobs=-1)

grid.fit(indenependent, dependent)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'friedman_mse', 'poisson'],
#                          'max_features': [None, 'sqrt', 'log2'],
#                          'n_estimators': [50, 100]},
#              verbose=3)

# %%
#print best parameter after tuning
re = grid.cv_results_
#print(re)

# grid_predictions = grid.predict(xTest)

#print classification report
# from sklearn.metrics import r2_score
# rScore = r2_score(yTest, grid_predictions)

print('The R-Score of the best perameter {}:'.format(grid.best_params_))
# Out:
# The R-Score of the best perameter {'criterion': 'poisson', 'max_features': 'log2', 'n_estimators': 100}:

# %%
tabel = pd.DataFrame.from_dict(re)

# %%
tabel
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.151465      0.021984         0.010374        0.003847
# 1        0.271553      0.021879         0.010599        0.003419
# 2        0.085641      0.008415         0.005257        0.001710
# 3        0.167653      0.009908         0.010527        0.006875
# 4        0.075884      0.009030         0.003012        0.000550
# 5        0.148019      0.007992         0.009621        0.003722
# 6        0.686172      0.018590         0.003799        0.001107
# 7        1.265414      0.058128         0.006831        0.000986
# 8        0.388815      0.035102         0.004453        0.002537
# 9        0.741827      0.092960         0.007928        0.002565
# 10       0.335299      0.015039         0.004569        0.001980
# 11       0.709639      0.010350         0.006737        0.002172
# 12       0.093618      0.004296         0.006235        0.002396
# 13       0.186085      0.006235         0.008143        0.001558
# 14       0.070829      0.012529         0.003604        0.001405
# 15       0.125321      0.005064         0.007745        0.002060
# 16       0.077147      0.035017         0.007350        0.005805
# 17       0.117723      0.016616         0.006985        0.003355
# 18       0.160474      0.016894         0.004637        0.002357
# 19       0.307796      0.024037         0.006089        0.001637
# 20       0.100778      0.004068         0.003853        0.001460
# 21       0.257924      0.011834         0.008350        0.002134
# 22       0.127951      0.014273         0.004082        0.001166
# 23       0.186642      0.023963         0.005971        0.002172
#
#    param_criterion param_max_features  param_n_estimators  \
# 0    squared_error               None                  50
# 1    squared_error               None                 100
# 2    squared_error               sqrt                  50
# 3    squared_error               sqrt                 100
# 4    squared_error               log2                  50
# 5    squared_error               log2                 100
# 6   absolute_error               None                  50
# 7   absolute_error               None                 100
# 8   absolute_error               sqrt                  50
# 9   absolute_error               sqrt                 100
# 10  absolute_error               log2                  50
# 11  absolute_error               log2                 100
# 12    friedman_mse               None                  50
# 13    friedman_mse               None                 100
# 14    friedman_mse               sqrt                  50
# 15    friedman_mse               sqrt                 100
# 16    friedman_mse               log2                  50
# 17    friedman_mse               log2                 100
# 18         poisson               None                  50
# 19         poisson               None                 100
# 20         poisson               sqrt                  50
# 21         poisson               sqrt                 100
# 22         poisson               log2                  50
# 23         poisson               log2                 100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.838877
# 1   {'criterion': 'squared_error', 'max_features':...           0.847898
# 2   {'criterion': 'squared_error', 'max_features':...           0.854815
# 3   {'criterion': 'squared_error', 'max_features':...           0.853834
# 4   {'criterion': 'squared_error', 'max_features':...           0.859291
# 5   {'criterion': 'squared_error', 'max_features':...           0.856859
# 6   {'criterion': 'absolute_error', 'max_features'...           0.839972
# 7   {'criterion': 'absolute_error', 'max_features'...           0.840289
# 8   {'criterion': 'absolute_error', 'max_features'...           0.852215
# 9   {'criterion': 'absolute_error', 'max_features'...           0.853972
# 10  {'criterion': 'absolute_error', 'max_features'...           0.854155
# 11  {'criterion': 'absolute_error', 'max_features'...           0.854646
# 12  {'criterion': 'friedman_mse', 'max_features': ...           0.846412
# 13  {'criterion': 'friedman_mse', 'max_features': ...           0.850368
# 14  {'criterion': 'friedman_mse', 'max_features': ...           0.856097
# 15  {'criterion': 'friedman_mse', 'max_features': ...           0.853675
# 16  {'criterion': 'friedman_mse', 'max_features': ...           0.861705
# 17  {'criterion': 'friedman_mse', 'max_features': ...           0.857772
# 18  {'criterion': 'poisson', 'max_features': None,...           0.849474
# 19  {'criterion': 'poisson', 'max_features': None,...           0.849261
# 20  {'criterion': 'poisson', 'max_features': 'sqrt...           0.851578
# 21  {'criterion': 'poisson', 'max_features': 'sqrt...           0.858557
# 22  {'criterion': 'poisson', 'max_features': 'log2...           0.860089
# 23  {'criterion': 'poisson', 'max_features': 'log2...           0.859672
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.773473           0.852501           0.815013
# 1            0.768422           0.854384           0.815873
# 2            0.782089           0.866855           0.823802
# 3            0.781653           0.866347           0.828615
# 4            0.772822           0.857766           0.829344
# 5            0.773387           0.859445           0.829052
# 6            0.768721           0.845596           0.829428
# 7            0.768894           0.851978           0.823204
# 8            0.777796           0.859550           0.827605
# 9            0.775796           0.859619           0.827924
# 10           0.781894           0.848528           0.830596
# 11           0.779933           0.852779           0.830361
# 12           0.773873           0.856508           0.814809
# 13           0.770012           0.857215           0.821615
# 14           0.780234           0.851708           0.827517
# 15           0.782195           0.860976           0.828061
# 16           0.779781           0.863544           0.826696
# 17           0.779979           0.860283           0.830510
# 18           0.773226           0.856895           0.817558
# 19           0.775787           0.855807           0.823086
# 20           0.779372           0.858481           0.826902
# 21           0.780515           0.858076           0.832620
# 22           0.776382           0.857820           0.822685
# 23           0.777374           0.865689           0.827333
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.835907         0.823154        0.027588               24
# 1            0.835608         0.824437        0.030929               21
# 2            0.841146         0.833741        0.029537                4
# 3            0.841013         0.834292        0.029181                2
# 4            0.841862         0.832217        0.031669               10
# 5            0.840944         0.831937        0.031290               11
# 6            0.834940         0.823732        0.028021               23
# 7            0.834624         0.823798        0.028976               22
# 8            0.842472         0.831928        0.029102               12
# 9            0.845118         0.832486        0.030305                8
# 10           0.842900         0.831615        0.026056               14
# 11           0.843968         0.832338        0.027571                9
# 12           0.835608         0.825442        0.029260               20
# 13           0.840044         0.827851        0.031312               18
# 14           0.842849         0.831681        0.027518               13
# 15           0.839607         0.832903        0.027782                7
# 16           0.835821         0.833509        0.030448                5
# 17           0.836824         0.833073        0.028948                6
# 18           0.841470         0.827725        0.030286               19
# 19           0.840344         0.828857        0.028720               17
# 20           0.841156         0.831498        0.028153               15
# 21           0.840475         0.834049        0.028591                3
# 22           0.840361         0.831468        0.030673               16
# 23           0.843691         0.834752        0.031639                1

# %%
age = float(input('Enter Age:'))
bmi = float(input('Enter BMI:'))
children = int(input('Enter Children:'))
sex_male = int(input('Enter Sex:'))
smoker_yes = int(input('Enter Smoker:'))
# Out:
# Enter Age: 30
# Enter BMI: 45
# Enter Children: 1
# Enter Sex: 1
# Enter Smoker: 0

# %%
futurePrediction = grid.predict([[age, bmi, children, sex_male, smoker_yes]])
print("Future Prediction={}".format(futurePrediction))
print(futurePrediction)
# Out:
# Future Prediction=[7617.7904373]
# [7617.7904373]
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

# %%
#Save the finalized model
import pickle
fileName = "best_rf_grid_model.sav"
pickle.dump(grid, open(fileName,'wb'))

# %%
#Read saved model
loadedModel = pickle.load(open("best_rf_grid_model.sav","rb")) #reload the model

# %%
result = loadedModel.predict([[30,45,1,1,0]]) #predict with new set of inputs
result
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# array([7617.7904373])
