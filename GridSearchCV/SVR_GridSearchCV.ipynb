# %%
import pandas as pd
dataset = pd.read_csv("../insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset = pd.get_dummies(dataset, drop_first=True)
dataset.astype(int)
# Out:
#       age  bmi  children  charges  sex_male  smoker_yes
# 0      19   27         0    16884         0           1
# 1      18   33         1     1725         1           0
# 2      28   33         3     4449         1           0
# 3      33   22         0    21984         1           0
# 4      32   28         0     3866         1           0
# ...   ...  ...       ...      ...       ...         ...
# 1333   50   30         3    10600         1           0
# 1334   18   31         0     2205         0           0
# 1335   18   36         0     1629         0           0
# 1336   21   25         0     2007         0           0
# 1337   61   29         0    29141         0           1
#
# [1338 rows x 6 columns]

# %%
#split independent and dependenet data
indenependent = dataset[['age','bmi', 'children', 'sex_male',  'smoker_yes']]
dependent = dataset['charges']

# %%
#split into training and test Data
from sklearn.model_selection import train_test_split
xTrain, xTest, yTrain, yTest = train_test_split(indenependent, dependent, test_size=0.30, random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
xTrain = sc.fit_transform(xTrain)
xTest = sc.transform(xTest)

# %%
xTrain
# Out:
# array([[-1.5330973 , -0.40713453, -0.89833872, -0.97676557, -0.50466988],
#        [-0.03364163,  0.32855417, -0.89833872, -0.97676557, -0.50466988],
#        [ 0.89459283,  2.56690911,  3.25603402, -0.97676557, -0.50466988],
#        ...,
#        [ 0.03776102, -0.91016269, -0.89833872,  1.02378711, -0.50466988],
#        [-1.46169465,  0.76659782, -0.89833872,  1.02378711, -0.50466988],
#        [-0.46205754, -1.96596021, -0.06746417, -0.97676557, -0.50466988]])

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVR
param_grid = {'kernel':['rbf', 'poly', 'sigmoid', 'linear'], 'C': [10, 100, 1000, 2000, 3000], 'gamma':['auto', 'scale']}

grid = GridSearchCV(SVR(), param_grid, refit=True, verbose = 3, n_jobs=-1)

grid.fit(xTrain, yTrain)
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# GridSearchCV(estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [10, 100, 1000, 2000, 3000],
#                          'gamma': ['auto', 'scale'],
#                          'kernel': ['rbf', 'poly', 'sigmoid', 'linear']},
#              verbose=3)

# %%
#print best parameter after tuning
re = grid.cv_results_
#print(re)

grid_predictions = grid.predict(xTest)

#print classification report
from sklearn.metrics import r2_score
rScore = r2_score(yTest, grid_predictions)

print('The R-Score of the best perameter {}:'.format(grid.best_params_), rScore)
# Out:
# The R-Score of the best perameter {'C': 3000, 'gamma': 'scale', 'kernel': 'poly'}: 0.8598930084494385

# %%
tabel = pd.DataFrame.from_dict(re)

# %%
tabel
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0        0.015618      0.003471         0.008453        0.003302       10
# 1        0.015389      0.004459         0.001891        0.000790       10
# 2        0.014888      0.001102         0.002460        0.000119       10
# 3        0.012403      0.002398         0.001144        0.000038       10
# 4        0.017560      0.008231         0.005162        0.002389       10
# 5        0.011552      0.004251         0.001252        0.000023       10
# 6        0.018206      0.002369         0.003174        0.001165       10
# 7        0.013211      0.003771         0.001200        0.000229       10
# 8        0.011916      0.003545         0.005371        0.002203      100
# 9        0.015852      0.005816         0.001755        0.001003      100
# 10       0.019743      0.004621         0.002297        0.000040      100
# 11       0.013852      0.003125         0.003067        0.003131      100
# ...

# %%
age = float(input('Enter Age:'))
bmi = float(input('Enter BMI:'))
children = int(input('Enter Children:'))
sex_male = int(input('Enter Sex:'))
smoker_yes = int(input('Enter Smoker:'))
# Out:
# Enter Age: 30
# Enter BMI: 45
# Enter Children: 1
# Enter Sex: 0
# Enter Smoker: 1

# %%
futurePrediction = grid.predict([[age, bmi, children, sex_male, smoker_yes]])
print("Future Prediction={}".format(futurePrediction))
print(futurePrediction)
# Out:
# Future Prediction=[562922.18260767]
# [562922.18260767]

# %%
#Save the finalized model
import pickle
fileName = "best_svrgrid_model.sav"
pickle.dump(grid, open(fileName,'wb'))

# %%
#Read saved model
loadedModel = pickle.load(open("best_svrgrid_model.sav","rb")) #reload the model

# %%
result = loadedModel.predict([[30,45,1,1,0]]) #predict with new set of inputs
result
# Out:
# array([1381166.89201699])
