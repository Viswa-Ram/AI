# %%
import pandas as pd
dataset = pd.read_csv("../insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset = pd.get_dummies(dataset, drop_first=True)
dataset.astype(int)
# Out:
#       age  bmi  children  charges  sex_male  smoker_yes
# 0      19   27         0    16884         0           1
# 1      18   33         1     1725         1           0
# 2      28   33         3     4449         1           0
# 3      33   22         0    21984         1           0
# 4      32   28         0     3866         1           0
# ...   ...  ...       ...      ...       ...         ...
# 1333   50   30         3    10600         1           0
# 1334   18   31         0     2205         0           0
# 1335   18   36         0     1629         0           0
# 1336   21   25         0     2007         0           0
# 1337   61   29         0    29141         0           1
#
# [1338 rows x 6 columns]

# %%
#split independent and dependenet data
independent = dataset[['age','bmi', 'children', 'sex_male',  'smoker_yes']]
dependent = dataset['charges']

# %%
#split into training and test Data
# from sklearn.model_selection import train_test_split
# xTrain, xTest, yTrain, yTest = train_test_split(indenependent, dependent, test_size=0.30, random_state=0)

# %%
#from sklearn.preprocessing import StandardScaler
# sc = StandardScaler()
# xTrain = sc.fit_transform(xTrain)
# xTest = sc.transform(xTest)

# %%
#xTrain
# Out:
# array([[-1.5330973 , -0.40713453, -0.89833872, -0.97676557, -0.50466988],
#        [-0.03364163,  0.32855417, -0.89833872, -0.97676557, -0.50466988],
#        [ 0.89459283,  2.56690911,  3.25603402, -0.97676557, -0.50466988],
#        ...,
#        [ 0.03776102, -0.91016269, -0.89833872,  1.02378711, -0.50466988],
#        [-1.46169465,  0.76659782, -0.89833872,  1.02378711, -0.50466988],
#        [-0.46205754, -1.96596021, -0.06746417, -0.97676557, -0.50466988]])

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor

param_grid = {'criterion':['squared_error', 'absolute_error', 'friedman_mse', 'poisson'], 'max_features': ['None', 'sqrt', 'log2'], 'splitter':["best", "random"]}

grid = GridSearchCV(DecisionTreeRegressor(), param_grid, refit=True, verbose = 3, n_jobs=-1)

grid.fit(independent, dependent)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/model_selection/_validation.py:540: FitFailedWarning:
# 40 fits failed out of a total of 120.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 7 fits failed with the following error:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.12/site-packages/sklearn/model_selection/_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "/opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "/opt/anaconda3/lib/python3.12/site-packages/sklearn/utils/_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'None' instead.
#
# --------------------------------------------------------------------------------
# 33 fits failed with the following error:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.12/site-packages/sklearn/model_selection/_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py", line 1466, in wrapper
#     estimator._validate_params()
#   File "/opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py", line 666, in _validate_params
#     validate_parameter_constraints(
#   File "/opt/anaconda3/lib/python3.12/site-packages/sklearn/utils/_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of DecisionTreeRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'None' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/model_selection/_search.py:1102: UserWarning: One or more of the test scores are non-finite: [       nan        nan 0.65537545 0.65694721 0.66931355 0.60358904
#         nan        nan 0.67029419 0.65473556 0.68377138 0.7169218
#         nan        nan 0.6736861  0.64362249 0.65731268 0.64697885
#         nan        nan 0.68471354 0.67264147 0.69896373 0.63968434]
#   warnings.warn(
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'friedman_mse', 'poisson'],
#                          'max_features': ['None', 'sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
#print best parameter after tuning
re = grid.cv_results_
#print(re)

# grid_predictions = grid.predict(xTest)

#print classification report
# from sklearn.metrics import r2_score
# rScore = r2_score(yTest, grid_predictions)

print('The R-Score of the best perameter {}:'.format(grid.best_params_))
# Out:
# The R-Score of the best perameter {'criterion': 'absolute_error', 'max_features': 'log2', 'splitter': 'random'}:

# %%
tabel = pd.DataFrame.from_dict(re)

# %%
tabel
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.000667      0.000128         0.000000        0.000000
# 1        0.000529      0.000179         0.000000        0.000000
# 2        0.003963      0.000891         0.000935        0.000117
# 3        0.001685      0.000259         0.000655        0.000049
# 4        0.002062      0.000575         0.000605        0.000056
# 5        0.001389      0.000303         0.000595        0.000085
# 6        0.000296      0.000035         0.000000        0.000000
# 7        0.000276      0.000023         0.000000        0.000000
# 8        0.011241      0.001733         0.000612        0.000049
# 9        0.011706      0.003568         0.000888        0.000492
# 10       0.011726      0.001245         0.000848        0.000404
# 11       0.011579      0.005467         0.000663        0.000120
# 12       0.000519      0.000092         0.000000        0.000000
# 13       0.000493      0.000149         0.000000        0.000000
# 14       0.003027      0.001197         0.001166        0.000858
# 15       0.001063      0.000057         0.000491        0.000016
# 16       0.001612      0.000305         0.000528        0.000035
# 17       0.001145      0.000175         0.000502        0.000022
# 18       0.000227      0.000031         0.000000        0.000000
# 19       0.000527      0.000204         0.000000        0.000000
# 20       0.003447      0.001717         0.000636        0.000148
# 21       0.002120      0.000072         0.000512        0.000026
# 22       0.003060      0.001094         0.000565        0.000113
# 23       0.002978      0.000794         0.000566        0.000043
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error               None           best
# 1    squared_error               None         random
# 2    squared_error               sqrt           best
# 3    squared_error               sqrt         random
# 4    squared_error               log2           best
# 5    squared_error               log2         random
# 6   absolute_error               None           best
# 7   absolute_error               None         random
# 8   absolute_error               sqrt           best
# 9   absolute_error               sqrt         random
# 10  absolute_error               log2           best
# 11  absolute_error               log2         random
# 12    friedman_mse               None           best
# 13    friedman_mse               None         random
# 14    friedman_mse               sqrt           best
# 15    friedman_mse               sqrt         random
# 16    friedman_mse               log2           best
# 17    friedman_mse               log2         random
# 18         poisson               None           best
# 19         poisson               None         random
# 20         poisson               sqrt           best
# 21         poisson               sqrt         random
# 22         poisson               log2           best
# 23         poisson               log2         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...                NaN
# 1   {'criterion': 'squared_error', 'max_features':...                NaN
# 2   {'criterion': 'squared_error', 'max_features':...           0.691581
# 3   {'criterion': 'squared_error', 'max_features':...           0.655222
# 4   {'criterion': 'squared_error', 'max_features':...           0.675086
# 5   {'criterion': 'squared_error', 'max_features':...           0.681053
# 6   {'criterion': 'absolute_error', 'max_features'...                NaN
# 7   {'criterion': 'absolute_error', 'max_features'...                NaN
# 8   {'criterion': 'absolute_error', 'max_features'...           0.647103
# 9   {'criterion': 'absolute_error', 'max_features'...           0.694049
# 10  {'criterion': 'absolute_error', 'max_features'...           0.702370
# 11  {'criterion': 'absolute_error', 'max_features'...           0.736634
# 12  {'criterion': 'friedman_mse', 'max_features': ...                NaN
# 13  {'criterion': 'friedman_mse', 'max_features': ...                NaN
# 14  {'criterion': 'friedman_mse', 'max_features': ...           0.657484
# 15  {'criterion': 'friedman_mse', 'max_features': ...           0.638269
# 16  {'criterion': 'friedman_mse', 'max_features': ...           0.681058
# 17  {'criterion': 'friedman_mse', 'max_features': ...           0.662653
# 18  {'criterion': 'poisson', 'max_features': 'None...                NaN
# 19  {'criterion': 'poisson', 'max_features': 'None...                NaN
# 20  {'criterion': 'poisson', 'max_features': 'sqrt...           0.701954
# 21  {'criterion': 'poisson', 'max_features': 'sqrt...           0.672908
# 22  {'criterion': 'poisson', 'max_features': 'log2...           0.755569
# 23  {'criterion': 'poisson', 'max_features': 'log2...           0.672092
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0                 NaN                NaN                NaN
# 1                 NaN                NaN                NaN
# 2            0.464529           0.710716           0.677212
# 3            0.554398           0.757492           0.652917
# 4            0.616746           0.741156           0.689384
# 5            0.360787           0.674078           0.684518
# 6                 NaN                NaN                NaN
# 7                 NaN                NaN                NaN
# 8            0.564112           0.690321           0.732484
# 9            0.572156           0.755451           0.640630
# 10           0.600387           0.771577           0.636177
# 11           0.692121           0.761736           0.695156
# 12                NaN                NaN                NaN
# 13                NaN                NaN                NaN
# 14           0.554785           0.692453           0.708686
# 15           0.565331           0.644549           0.644437
# 16           0.598221           0.490555           0.793877
# 17           0.589763           0.612305           0.673359
# 18                NaN                NaN                NaN
# 19                NaN                NaN                NaN
# 20           0.572383           0.724411           0.727546
# 21           0.557676           0.735818           0.712320
# 22           0.558923           0.758916           0.739461
# 23           0.530938           0.670668           0.692851
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0                 NaN              NaN             NaN               17
# 1                 NaN              NaN             NaN               17
# 2            0.732839         0.655375        0.097235               11
# 3            0.664707         0.656947        0.064351               10
# 4            0.624196         0.669314        0.045599                8
# 5            0.617509         0.603589        0.123827               16
# 6                 NaN              NaN             NaN               17
# 7                 NaN              NaN             NaN               17
# 8            0.717450         0.670294        0.060506                7
# 9            0.611392         0.654736        0.064165               12
# 10           0.708347         0.683771        0.059796                4
# 11           0.698962         0.716922        0.027598                1
# 12                NaN              NaN             NaN               17
# 13                NaN              NaN             NaN               17
# 14           0.755022         0.673686        0.067220                5
# 15           0.725527         0.643622        0.050731               14
# 16           0.722853         0.657313        0.104699                9
# 17           0.696815         0.646979        0.039752               13
# 18                NaN              NaN             NaN               17
# 19                NaN              NaN             NaN               17
# 20           0.697274         0.684714        0.057417                3
# 21           0.684485         0.672641        0.061519                6
# 22           0.681950         0.698964        0.075285                2
# 23           0.631873         0.639684        0.057834               15

# %%
age = float(input('Enter Age:'))
bmi = float(input('Enter BMI:'))
children = int(input('Enter Children:'))
sex_male = int(input('Enter Sex:'))
smoker_yes = int(input('Enter Smoker:'))
# Out:
# Enter Age: 30
# Enter BMI: 45
# Enter Children: 1
# Enter Sex: 0
# Enter Smoker: 1

# %%
futurePrediction = grid.predict([[age, bmi, children, sex_male, smoker_yes]])
print("Future Prediction={}".format(futurePrediction))
print(futurePrediction)
# Out:
# Future Prediction=[19107.7796]
# [19107.7796]
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(

# %%
#Save the finalized model
import pickle
fileName = "best_dt_grid_model.sav"
pickle.dump(grid, open(fileName,'wb'))

# %%
#Read saved model
loadedModel = pickle.load(open("best_dt_grid_model.sav","rb")) #reload the model

# %%
result = loadedModel.predict([[30,45,1,1,0]]) #predict with new set of inputs
result
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# array([3875.7341])
