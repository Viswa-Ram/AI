# %%
import pandas as pd
dataset = pd.read_csv("../insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset = pd.get_dummies(dataset, drop_first=True)
dataset.astype(int)
# Out:
#       age  bmi  children  charges  sex_male  smoker_yes
# 0      19   27         0    16884         0           1
# 1      18   33         1     1725         1           0
# 2      28   33         3     4449         1           0
# 3      33   22         0    21984         1           0
# 4      32   28         0     3866         1           0
# ...   ...  ...       ...      ...       ...         ...
# 1333   50   30         3    10600         1           0
# 1334   18   31         0     2205         0           0
# 1335   18   36         0     1629         0           0
# 1336   21   25         0     2007         0           0
# 1337   61   29         0    29141         0           1
#
# [1338 rows x 6 columns]

# %%
#split independent and dependenet data
independent = dataset[['age','bmi', 'children', 'sex_male',  'smoker_yes']]
dependent = dataset['charges']

# %%
#split into training and test Data
# from sklearn.model_selection import train_test_split
# xTrain, xTest, yTrain, yTest = train_test_split(indenependent, dependent, test_size=0.30, random_state=0)

# %%
#from sklearn.preprocessing import StandardScaler
# sc = StandardScaler()
# xTrain = sc.fit_transform(xTrain)
# xTest = sc.transform(xTest)

# %%
#xTrain
# Out:
# array([[-1.5330973 , -0.40713453, -0.89833872, -0.97676557, -0.50466988],
#        [-0.03364163,  0.32855417, -0.89833872, -0.97676557, -0.50466988],
#        [ 0.89459283,  2.56690911,  3.25603402, -0.97676557, -0.50466988],
#        ...,
#        [ 0.03776102, -0.91016269, -0.89833872,  1.02378711, -0.50466988],
#        [-1.46169465,  0.76659782, -0.89833872,  1.02378711, -0.50466988],
#        [-0.46205754, -1.96596021, -0.06746417, -0.97676557, -0.50466988]])

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor

param_grid = {'criterion':['squared_error', 'absolute_error', 'friedman_mse', 'poisson'], 'max_features': [None, 'sqrt', 'log2'], 'splitter':["best", "random"]}

grid = GridSearchCV(DecisionTreeRegressor(), param_grid, refit=True, verbose = 3, n_jobs=-1)

grid.fit(independent, dependent)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'friedman_mse', 'poisson'],
#                          'max_features': [None, 'sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
#print best parameter after tuning
re = grid.cv_results_
#print(re)

# grid_predictions = grid.predict(xTest)

#print classification report
# from sklearn.metrics import r2_score
# rScore = r2_score(yTest, grid_predictions)

print('The R-Score of the best perameter {}:'.format(grid.best_params_))
# Out:
# The R-Score of the best perameter {'criterion': 'absolute_error', 'max_features': None, 'splitter': 'best'}:

# %%
tabel = pd.DataFrame.from_dict(re)

# %%
tabel
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.008030      0.002564         0.002745        0.000748
# 1        0.005096      0.001295         0.002266        0.001608
# 2        0.002035      0.000422         0.000826        0.000310
# 3        0.001388      0.000331         0.000558        0.000029
# 4        0.001667      0.000127         0.000570        0.000027
# 5        0.001185      0.000069         0.000538        0.000021
# 6        0.025432      0.001666         0.001032        0.000436
# 7        0.018301      0.002971         0.001294        0.001229
# 8        0.013871      0.002097         0.000676        0.000059
# 9        0.011743      0.002134         0.001084        0.000456
# 10       0.015498      0.003092         0.001152        0.000494
# 11       0.012516      0.003534         0.000745        0.000150
# 12       0.003518      0.001259         0.000918        0.000435
# 13       0.002444      0.000622         0.001217        0.000603
# 14       0.002442      0.001253         0.000796        0.000443
# 15       0.001107      0.000069         0.000510        0.000018
# 16       0.001498      0.000099         0.000739        0.000420
# 17       0.001111      0.000105         0.000502        0.000036
# 18       0.003393      0.000149         0.000616        0.000138
# 19       0.003737      0.001494         0.000768        0.000458
# 20       0.004163      0.001349         0.000813        0.000296
# 21       0.004501      0.001457         0.001014        0.000497
# 22       0.003187      0.001185         0.000701        0.000363
# 23       0.002305      0.000151         0.000499        0.000012
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error               None           best
# 1    squared_error               None         random
# 2    squared_error               sqrt           best
# 3    squared_error               sqrt         random
# 4    squared_error               log2           best
# 5    squared_error               log2         random
# 6   absolute_error               None           best
# 7   absolute_error               None         random
# 8   absolute_error               sqrt           best
# 9   absolute_error               sqrt         random
# 10  absolute_error               log2           best
# 11  absolute_error               log2         random
# 12    friedman_mse               None           best
# 13    friedman_mse               None         random
# 14    friedman_mse               sqrt           best
# 15    friedman_mse               sqrt         random
# 16    friedman_mse               log2           best
# 17    friedman_mse               log2         random
# 18         poisson               None           best
# 19         poisson               None         random
# 20         poisson               sqrt           best
# 21         poisson               sqrt         random
# 22         poisson               log2           best
# 23         poisson               log2         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.722206
# 1   {'criterion': 'squared_error', 'max_features':...           0.676807
# 2   {'criterion': 'squared_error', 'max_features':...           0.760605
# 3   {'criterion': 'squared_error', 'max_features':...           0.701472
# 4   {'criterion': 'squared_error', 'max_features':...           0.689945
# 5   {'criterion': 'squared_error', 'max_features':...           0.741266
# 6   {'criterion': 'absolute_error', 'max_features'...           0.741086
# 7   {'criterion': 'absolute_error', 'max_features'...           0.725893
# 8   {'criterion': 'absolute_error', 'max_features'...           0.619024
# 9   {'criterion': 'absolute_error', 'max_features'...           0.691476
# 10  {'criterion': 'absolute_error', 'max_features'...           0.723187
# 11  {'criterion': 'absolute_error', 'max_features'...           0.702406
# 12  {'criterion': 'friedman_mse', 'max_features': ...           0.720462
# 13  {'criterion': 'friedman_mse', 'max_features': ...           0.685868
# 14  {'criterion': 'friedman_mse', 'max_features': ...           0.731385
# 15  {'criterion': 'friedman_mse', 'max_features': ...           0.630445
# 16  {'criterion': 'friedman_mse', 'max_features': ...           0.781598
# 17  {'criterion': 'friedman_mse', 'max_features': ...           0.624566
# 18  {'criterion': 'poisson', 'max_features': None,...           0.744345
# 19  {'criterion': 'poisson', 'max_features': None,...           0.668195
# 20  {'criterion': 'poisson', 'max_features': 'sqrt...           0.720542
# 21  {'criterion': 'poisson', 'max_features': 'sqrt...           0.695040
# 22  {'criterion': 'poisson', 'max_features': 'log2...           0.665074
# 23  {'criterion': 'poisson', 'max_features': 'log2...           0.682687
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.613644           0.715805           0.699485
# 1            0.634085           0.746473           0.698589
# 2            0.603621           0.728933           0.699286
# 3            0.418849           0.654784           0.647034
# 4            0.585279           0.706945           0.662829
# 5            0.622303           0.728502           0.573090
# 6            0.630151           0.724819           0.722491
# 7            0.665585           0.701298           0.732697
# 8            0.548481           0.724006           0.753074
# 9            0.423105           0.690242           0.592266
# 10           0.659925           0.715726           0.480890
# 11           0.512052           0.744415           0.655848
# 12           0.641517           0.736157           0.740805
# 13           0.564198           0.747370           0.740809
# 14           0.584876           0.703973           0.697221
# 15           0.551117           0.730341           0.736949
# 16           0.621117           0.647854           0.660228
# 17           0.547012           0.650859           0.694350
# 18           0.671979           0.758010           0.719096
# 19           0.677583           0.715905           0.711664
# 20           0.538285           0.664921           0.689374
# 21           0.540735           0.740051           0.660885
# 22           0.568229           0.703865           0.694206
# 23           0.523617           0.649768           0.658880
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.664259         0.683080        0.040116               10
# 1            0.718403         0.694871        0.038083                7
# 2            0.710445         0.700578        0.052739                5
# 3            0.711992         0.626826        0.107023               23
# 4            0.713230         0.671645        0.046577               13
# 5            0.560342         0.645101        0.076280               21
# 6            0.759471         0.715604        0.044740                1
# 7            0.685109         0.702116        0.025000                4
# 8            0.711414         0.671200        0.076015               14
# 9            0.647768         0.608971        0.099742               24
# 10           0.711356         0.658217        0.091433               17
# 11           0.653731         0.653690        0.078320               18
# 12           0.684411         0.704670        0.037270                3
# 13           0.727329         0.693115        0.067913                8
# 14           0.727219         0.688935        0.053648                9
# 15           0.663012         0.662373        0.068671               16
# 16           0.695202         0.681200        0.055565               11
# 17           0.715002         0.646358        0.058958               19
# 18           0.683581         0.715402        0.033361                2
# 19           0.706877         0.696045        0.019350                6
# 20           0.712178         0.665060        0.066274               15
# 21           0.579747         0.643292        0.073356               22
# 22           0.758206         0.677916        0.062580               12
# 23           0.712343         0.645459        0.064659               20

# %%
age = float(input('Enter Age:'))
bmi = float(input('Enter BMI:'))
children = int(input('Enter Children:'))
sex_male = int(input('Enter Sex:'))
smoker_yes = int(input('Enter Smoker:'))
# Out:
# Enter Age: 30
# Enter BMI: 45
# Enter Children: 1
# Enter Sex: 1
# Enter Smoker: 0

# %%
futurePrediction = grid.predict([[age, bmi, children, sex_male, smoker_yes]])
print("Future Prediction={}".format(futurePrediction))
print(futurePrediction)
# Out:
# Future Prediction=[3471.4096]
# [3471.4096]
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(

# %%
#Save the finalized model
import pickle
fileName = "best_dt_grid_model.sav"
pickle.dump(grid, open(fileName,'wb'))

# %%
#Read saved model
loadedModel = pickle.load(open("best_dt_grid_model.sav","rb")) #reload the model

# %%
result = loadedModel.predict([[30,45,1,1,0]]) #predict with new set of inputs
result
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# array([3471.4096])
